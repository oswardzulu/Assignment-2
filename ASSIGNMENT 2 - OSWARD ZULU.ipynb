# %%
#ASSIGNMENT 2 - OSWARD ZULU

# %%
# Imports needed to complete this assignment
import pandas as pd

# %%
#Read the CSV file into a dataframe
ibm = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
ibm.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#1. SHOW A BREAKDOWN OF DISTANCE FROM HOME BY JOB ROLE AND ATTRITION.

dist_by_job_and_attrition = ibm.groupby(['DistanceFromHome','Attrition', 'JobRole']).agg({'JobRole': ['count']})
dist_by_job_and_attrition.head(35)
# Out:
#                                                      JobRole
#                                                        count
# DistanceFromHome Attrition JobRole
# 1                No        Healthcare Representative      23
#                            Human Resources                 8
#                            Laboratory Technician          27
#                            Manager                        13
#                            Manufacturing Director         23
#                            Research Director              13
#                            Research Scientist             40
#                            Sales Executive                33
#                            Sales Representative            2
#                  Yes       Human Resources                 1
#                            Laboratory Technician           4
#                            Manufacturing Director          1
#                            Research Scientist              7
# ...

# %%
#ALSO SHOWING A BREAKDOWN OF DISTANCE FROM HOME BY JOB ROLE.

dist_by_job = ibm.groupby(['DistanceFromHome','JobRole']).agg({'JobRole': ['count']})
dist_by_job.head(20)
# Out:
#                                            JobRole
#                                              count
# DistanceFromHome JobRole
# 1                Healthcare Representative      23
#                  Human Resources                 9
#                  Laboratory Technician          31
#                  Manager                        13
#                  Manufacturing Director         24
#                  Research Director              13
#                  Research Scientist             47
#                  Sales Executive                39
#                  Sales Representative            9
# 2                Healthcare Representative      15
#                  Human Resources                10
#                  Laboratory Technician          36
#                  Manager                        25
#                  Manufacturing Director         24
#                  Research Director              11
#                  Research Scientist             36
# ...

# %%
#ALSO SHOWING A BREAKDOWN OF DISTANCE FROM HOME BY ATTRITION.

dist_by_attrition = ibm.groupby(['DistanceFromHome','Attrition']).agg({'Attrition': ['count']})
dist_by_attrition.head(20)
# Out:
#                            Attrition
#                                count
# DistanceFromHome Attrition
# 1                No              182
#                  Yes              26
# 2                No              183
#                  Yes              28
# 3                No               70
#                  Yes              14
# 4                No               55
#                  Yes               9
# 5                No               55
#                  Yes              10
# 6                No               52
#                  Yes               7
# 7                No               73
#                  Yes              11
# 8                No               70
#                  Yes              10
# 9                No               67
#                  Yes              18
# 10               No               75
#                  Yes              11

# %%
#2. COMPARE THE AVERAGE MONTHLY INCOME BY EDUCATION AND ATTRITION.

avg_month_income_by_edu_and_attrition = ibm.groupby(['EducationField','Attrition']).agg({'MonthlyIncome': ['mean']})
avg_month_income_by_edu_and_attrition
# Out:
#                            MonthlyIncome
#                                     mean
# EducationField   Attrition
# Human Resources  No          8579.950000
#                  Yes         3416.000000
# Life Sciences    No          6775.437137
#                  Yes         4650.022472
# Marketing        No          7569.774194
#                  Yes         6564.942857
# Medical          No          6800.805486
#                  Yes         4659.269841
# Other            No          6422.704225
#                  Yes         3805.000000
# Technical Degree No          6284.810000
#                  Yes         4112.968750

# %%
#ALSO COMPARING THE AVERAGE MONTHLY INCOME BY EDUCATION.

avg_month_income_by_education = ibm.groupby(['EducationField']).agg({'MonthlyIncome': ['mean']})
avg_month_income_by_education
# Out:
#                  MonthlyIncome
#                           mean
# EducationField
# Human Resources    7241.148148
# Life Sciences      6463.288779
# Marketing          7348.584906
# Medical            6510.036638
# Other              6071.548780
# Technical Degree   5758.303030

# %%
#ALSO COMPARING THE AVERAGE MONTHLY INCOME BY ATTRITION.

avg_month_income_by_attrition = ibm.groupby(['Attrition']).agg({'MonthlyIncome': ['mean']})
avg_month_income_by_attrition
# Out:
#           MonthlyIncome
#                    mean
# Attrition
# No          6832.739659
# Yes         4787.092827
